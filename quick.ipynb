# %%
import os
from salesgpt.agents import SalesGPT
from langchain_community.chat_models import ChatLiteLLM

from dotenv import load_dotenv
load_dotenv() # make sure you have .env file with your API keys, eg., OPENAI_API_KEY=sk-xxx, MINDWARE_API_KEY etc.

# select your model - we support 50+ LLMs via LiteLLM https://docs.litellm.ai/docs/providers
llm = ChatLiteLLM(temperature=0.4, model_name="gpt-4-0125-preview") 
                            
sales_agent = SalesGPT.from_llm(llm, use_tools=True, verbose=False,
                            product_catalog = "examples/sample_product_catalog.txt",
                            salesperson_name="Ted Lasso",
                            salesperson_role="Sales Representative",
                            company_name="Sleep Haven",
                            company_business='''Sleep Haven 
                            is a premium mattress company that provides
                            customers with the most comfortable and
                            supportive sleeping experience possible. 
                            We offer a range of high-quality mattresses,
                            pillows, and bedding accessories 
                            that are designed to meet the unique 
                            needs of our customers.'''
                            )
sales_agent.seed_agent()
sales_agent.determine_conversation_stage() # optional for demonstration, built into the prompt
# agent 
sales_agent.step()

# user
user_input = input('Your response: ') # Yea, sure
sales_agent.human_step(user_input)

# agent
sales_agent.determine_conversation_stage() # optional for demonstration, built into the prompt
sales_agent.step()

# user
user_input = input('Your response: ') # What pricing do you have for your mattresses?
sales_agent.human_step(user_input)

# agent
sales_agent.determine_conversation_stage() # optional for demonstration, built into the prompt
sales_agent.step()
# Out:
# salesgpt.logger 2024-05-19 14:50:06,658 - INFO - Running from_llm: --- 0.0 seconds ---
# salesgpt.logger 2024-05-19 14:50:06,659 - INFO - Running from_llm: --- 0.0 seconds ---
# salesgpt.logger 2024-05-19 14:50:06,660 - INFO - Running from_llm: --- 0.0 seconds ---
# langchain.text_splitter 2024-05-19 14:50:06,661 - WARNING - Created a chunk of size 940, which is longer than the specified 10
# langchain.text_splitter 2024-05-19 14:50:06,661 - WARNING - Created a chunk of size 844, which is longer than the specified 10
# langchain.text_splitter 2024-05-19 14:50:06,662 - WARNING - Created a chunk of size 837, which is longer than the specified 10
# chromadb.api.segment 2024-05-19 14:50:06,715 - INFO - Collection product-knowledge-base is not created.
# STAGE ANALYZER PROMPT input_variables=['conversation_history', 'conversation_stage_id', 'conversation_stages'] template='\nYou are a sales assistant helping your sales agent to determine which stage of a sales conversation should the agent stay at or move to when talking to a user.\nStart of conversation history:\n===\n{conversation_history}\n===\nEnd of conversation history.\n\nCurrent Conversation stage is: {conversation_stage_id}\n\nNow determine what should be the next immediate conversation stage for the agent in the sales conversation by selecting only from the following options:\n{conversation_stages}\n\nThe answer needs to be one number only from the conversation stages, no words.\nOnly use the current conversation stage and conversation history to determine your answer!\nIf the conversation history is empty, always start with Introduction!\nIf you think you should stay in the same conversation stage until user gives more input, just output the current conversation stage.\nDo not answer anything else nor add anything to you answer.'
# httpx 2024-05-19 14:50:07,270 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[3], line 11
#       8 # select your model - we support 50+ LLMs via LiteLLM https://docs.litellm.ai/docs/providers
#       9 llm = ChatLiteLLM(temperature=0.4, model_name="gpt-4-0125-preview")
# ---> 11 sales_agent = SalesGPT.from_llm(llm, use_tools=True, verbose=False,
#      12                             product_catalog = "examples/sample_product_catalog.txt",
#      13                             salesperson_name="Ted Lasso",
#      14                             salesperson_role="Sales Representative",
#      15                             company_name="Sleep Haven",
#      16                             company_business='''Sleep Haven
#      17                             is a premium mattress company that provides
#      18                             customers with the most comfortable and
#      19                             supportive sleeping experience possible.
#      20                             We offer a range of high-quality mattresses,
#      21                             pillows, and bedding accessories
#      22                             that are designed to meet the unique
#      23                             needs of our customers.'''
#      24                             )
#      25 sales_agent.seed_agent()
#      26 sales_agent.determine_conversation_stage() # optional for demonstration, built into the prompt
#
# File d:\SalesGPT\salesgpt\logger.py:46, in time_logger.<locals>.wrapper(*args, **kwargs)
#      43 @wraps(func)
#      44 def wrapper(*args, **kwargs):
#      45     start_time = time.time()  # Start time before function execution
# ---> 46     result = func(*args, **kwargs)  # Function execution
#      47     end_time = time.time()  # End time after function execution
#      48     execution_time = end_time - start_time  # Calculate execution time
#
# File d:\SalesGPT\salesgpt\agents.py:599, in SalesGPT.from_llm(cls, llm, verbose, **kwargs)
#     597 if use_tools:
#     598     product_catalog = kwargs.pop("product_catalog", None)
# --> 599     tools = get_tools(product_catalog)
#     601     prompt = CustomPromptTemplateForTools(
#     602         template=SALES_AGENT_TOOLS_PROMPT,
#     603         tools_getter=lambda x: tools,
#    (...)
#     615         ],
#     616     )
#     617     llm_chain = LLMChain(llm=llm, prompt=prompt, verbose=verbose)
#
# File d:\SalesGPT\salesgpt\tools.py:253, in get_tools(product_catalog)
#     248 def get_tools(product_catalog):
#     249     # query to get_tools can be used to be embedded and relevant tools found
#     250     # see here: https://langchain-langchain.vercel.app/docs/use_cases/agents/custom_agent_with_plugin_retrieval#tool-retriever
#     251
#     252     # we only use four tools for now, but this is highly extensible!
# --> 253     knowledge_base = setup_knowledge_base(product_catalog)
#     254     tools = [
#     255         Tool(
#     256             name="ProductSearch",
#    (...)
#     275         )
#     276     ]
#     278     return tools
#
# File d:\SalesGPT\salesgpt\tools.py:33, in setup_knowledge_base(product_catalog, model_name)
#      30 llm = ChatOpenAI(model_name="gpt-4-0125-preview", temperature=0)
#      32 embeddings = OpenAIEmbeddings()
# ---> 33 docsearch = Chroma.from_texts(
#      34     texts, embeddings, collection_name="product-knowledge-base"
#      35 )
#      37 knowledge_base = RetrievalQA.from_chain_type(
#      38     llm=llm, chain_type="stuff", retriever=docsearch.as_retriever()
#      39 )
#      40 return knowledge_base
#
# File d:\SalesGPT\env\Lib\site-packages\langchain_community\vectorstores\chroma.py:736, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     728     from chromadb.utils.batch_utils import create_batches
#     730     for batch in create_batches(
#     731         api=chroma_collection._client,
#     732         ids=ids,
#     733         metadatas=metadatas,
#     734         documents=texts,
#     735     ):
# --> 736         chroma_collection.add_texts(
#     737             texts=batch[3] if batch[3] else [],
#     738             metadatas=batch[2] if batch[2] else None,
#     739             ids=batch[0],
#     740         )
#     741 else:
#     742     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
# File d:\SalesGPT\env\Lib\site-packages\langchain_community\vectorstores\chroma.py:275, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     273 texts = list(texts)
#     274 if self._embedding_function is not None:
# --> 275     embeddings = self._embedding_function.embed_documents(texts)
#     276 if metadatas:
#     277     # fill metadatas with empty dicts if somebody
#     278     # did not specify metadata for all texts
#     279     length_diff = len(texts) - len(metadatas)
#
# File d:\SalesGPT\env\Lib\site-packages\langchain_openai\embeddings\base.py:482, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     479 # NOTE: to keep things simple, we assume the list may contain texts longer
#     480 #       than the maximum context and use length-safe embedding function.
#     481 engine = cast(str, self.deployment)
# --> 482 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File d:\SalesGPT\env\Lib\site-packages\langchain_openai\embeddings\base.py:325, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     323 batched_embeddings: List[List[float]] = []
#     324 for i in _iter:
# --> 325     response = self.client.create(
#     326         input=tokens[i : i + _chunk_size], **self._invocation_params
#     327     )
#     328     if not isinstance(response, dict):
#     329         response = response.dict()
#
# File d:\SalesGPT\env\Lib\site-packages\openai\resources\embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File d:\SalesGPT\env\Lib\site-packages\openai\_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\SalesGPT\env\Lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File d:\SalesGPT\env\Lib\site-packages\openai\_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1027     stream_cls=stream_cls,
#    1028 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: xx. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
